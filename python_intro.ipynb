# %% [markdown]
# <a href="https://colab.research.google.com/github/juvi-160/IIIT-H-Internship/blob/main/python_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
school = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/School%20Ratings.csv')

# %%
school.head()
# Out:
#                           name  school_rating   size  reduced_lunch  \
# 0  Allendale Elementary School            5.0  851.0           10.0
# 1          Anderson Elementary            2.0  412.0           71.0
# 2             Avoca Elementary            4.0  482.0           43.0
# 3                Bailey Middle            0.0  394.0           91.0
# 4          Barfield Elementary            4.0  948.0           26.0
#
#    state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# 0                 90.2                 95.8             15.7         Public
# 1                 32.8                 37.3             12.8         Public
# 2                 78.4                 83.6             16.6         Public
# 3                  1.6                  1.0             13.1  Public Magnet
# 4                 85.3                 89.2             14.8         Public
#
#    avg_score_15  avg_score_16  full_time_teachers  percent_black  \
# ...

# %%
school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 347 non-null    object
#  1   school_rating        347 non-null    float64
#  2   size                 347 non-null    float64
#  3   reduced_lunch        347 non-null    float64
#  4   state_percentile_16  347 non-null    float64
#  5   state_percentile_15  341 non-null    float64
#  6   stu_teach_ratio      347 non-null    float64
#  7   school_type          347 non-null    object
#  8   avg_score_15         341 non-null    float64
#  9   avg_score_16         347 non-null    float64
#  10  full_time_teachers   347 non-null    float64
#  11  percent_black        347 non-null    float64
#  12  percent_white        347 non-null    float64
#  13  percent_asian        347 non-null    float64
#  14  percent_hispanic     347 non-null    float64
# ...

# %%
school.describe()
# Out:
#        school_rating         size  reduced_lunch  state_percentile_16  \
# count     347.000000   347.000000     347.000000           347.000000
# mean        2.968300   699.472622      50.279539            58.801729
# std         1.690377   400.598636      25.480236            32.540747
# min         0.000000    53.000000       2.000000             0.200000
# 25%         2.000000   420.500000      30.000000            30.950000
# 50%         3.000000   595.000000      51.000000            66.400000
# 75%         4.000000   851.000000      71.500000            88.000000
# max         5.000000  2314.000000      98.000000            99.800000
#
#        state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# count           341.000000       347.000000    341.000000    347.000000
# mean             58.249267        15.461671     57.004692     57.049856
# std              32.702630         5.725170     26.696450     27.968974
# ...

# %%
school.describe(include='all')
# Out:
#                       name  school_rating         size  reduced_lunch  \
# count                  347     347.000000   347.000000     347.000000
# unique                 341            NaN          NaN            NaN
# top     Liberty Elementary            NaN          NaN            NaN
# freq                     3            NaN          NaN            NaN
# mean                   NaN       2.968300   699.472622      50.279539
# std                    NaN       1.690377   400.598636      25.480236
# min                    NaN       0.000000    53.000000       2.000000
# 25%                    NaN       2.000000   420.500000      30.000000
# 50%                    NaN       3.000000   595.000000      51.000000
# 75%                    NaN       4.000000   851.000000      71.500000
# max                    NaN       5.000000  2314.000000      98.000000
#
#         state_percentile_16  state_percentile_15  stu_teach_ratio school_type  \
# ...

# %%
#display shape
school.shape
# Out:
# (347, 15)

# %%
#display column labels
school.columns
# Out:
# Index(['name', 'school_rating', 'size', 'reduced_lunch', 'state_percentile_16',
#        'state_percentile_15', 'stu_teach_ratio', 'school_type', 'avg_score_15',
#        'avg_score_16', 'full_time_teachers', 'percent_black', 'percent_white',
#        'percent_asian', 'percent_hispanic'],
#       dtype='object')

# %%
#select a column as a series
school['name']
# Out:
# 0       Allendale Elementary School
# 1               Anderson Elementary
# 2                  Avoca Elementary
# 3                     Bailey Middle
# 4               Barfield Elementary
#                    ...
# 342    Winfree Bryant Middle School
# 343      Winstead Elementary School
# 344             Woodland Elementary
# 345          Woodland Middle School
# 346                   Wright Middle
# Name: name, Length: 347, dtype: object

# %%
school['name'].shape
# Out:
# (347,)

# %%
#selecy a column as a dataframe
school[['name']]
# Out:
#                              name
# 0     Allendale Elementary School
# 1             Anderson Elementary
# 2                Avoca Elementary
# 3                   Bailey Middle
# 4             Barfield Elementary
# ..                            ...
# 342  Winfree Bryant Middle School
# 343    Winstead Elementary School
# 344           Woodland Elementary
# 345        Woodland Middle School
# 346                 Wright Middle
#
# [347 rows x 1 columns]

# %%
#unique categories in a column
school['name'].unique()
# Out:
# array(['Allendale Elementary School', 'Anderson Elementary',
#        'Avoca Elementary', 'Bailey Middle', 'Barfield Elementary',
#        'Barkers Mill Elementary School', 'Barksdale Elementary',
#        'Beech Elementary', 'Beech Senior High School', 'Bellevue Middle',
#        'Bellshire Elementary', 'Benny C. Bills Elementary School',
#        'Black Fox Elementary', 'Blackman Elementary School',
#        'Blackman High School', 'Blackman Middle School',
#        'Bluff City Elementary', 'Bluff City Middle School',
#        'Boones Creek Middle School',
#        'Bradley Academy - An Arts Integrated School',
#        'Brentwood High School', 'Brentwood Middle School',
#        "Brown's Chapel Elementary School", 'Buchanan Elementary',
#        'Buena Vista Elementary', 'Byars Dowdy Elementary',
#        'Byrns L Darden Elementary', 'Caldwell Elementary',
#        'Cameron College Preparatory', 'Carmel Elementary',
# ...

# %%
#no of unique categories in a column
school['name'].nunique()
# Out:
# 341

# %%
school['name'].value_counts()
# Out:
# name
# Liberty Elementary                     3
# South Side Elementary                  2
# Johnson Elementary                     2
# Eakin Elementary                       2
# Rock Springs Elementary                2
#                                       ..
# Hillsboro Elementary/ Middle School    1
# Highland Park Elementary               1
# Hickman Elementary                     1
# Hendersonville High School             1
# Wright Middle                          1
# Name: count, Length: 341, dtype: int64

# %%
#count missing values
school.isna().sum()
# Out:
# name                   0
# school_rating          0
# size                   0
# reduced_lunch          0
# state_percentile_16    0
# state_percentile_15    6
# stu_teach_ratio        0
# school_type            0
# avg_score_15           6
# avg_score_16           0
# full_time_teachers     0
# percent_black          0
# percent_white          0
# percent_asian          0
# percent_hispanic       0
# dtype: int64

# %%
school.isnull().sum()
# Out:
# name                   0
# school_rating          0
# size                   0
# reduced_lunch          0
# state_percentile_16    0
# state_percentile_15    6
# stu_teach_ratio        0
# school_type            0
# avg_score_15           6
# avg_score_16           0
# full_time_teachers     0
# percent_black          0
# percent_white          0
# percent_asian          0
# percent_hispanic       0
# dtype: int64
